# %% [markdown]
# ## Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#import Citypy
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import requests
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # print(city) or # print (i, city) 
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
     # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    #print(city_url)
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description":city_weather_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | asau
# Processing Record 4 of Set 1 | grindavik
# Processing Record 5 of Set 1 | surt
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 1 | ouallam
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | juneau
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | shimoda
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | hambantota
# Processing Record 19 of Set 1 | akyab
# Processing Record 20 of Set 1 | kizilskoye
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | vao
# Processing Record 26 of Set 1 | buchanan
# Processing Record 27 of Set 1 | carauari
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | kieta
# Processing Record 34 of Set 1 | lompoc
# Processing Record 35 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 1 | olafsvik
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | goba
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | ano mera
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | zalantun
# Processing Record 46 of Set 1 | tromso
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | karaman
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | berlevag
# Processing Record 4 of Set 2 | sena madureira
# Processing Record 5 of Set 2 | yinchuan
# Processing Record 6 of Set 2 | jieshi
# Processing Record 7 of Set 2 | klyuchi
# Processing Record 8 of Set 2 | redlands
# Processing Record 9 of Set 2 | san jose
# Processing Record 10 of Set 2 | the valley
# Processing Record 11 of Set 2 | bhadasar
# Processing Record 12 of Set 2 | batticaloa
# Processing Record 13 of Set 2 | kashi
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | radstadt
# Processing Record 16 of Set 2 | vilela
# Processing Record 17 of Set 2 | dabola
# Processing Record 18 of Set 2 | vila velha
# Processing Record 19 of Set 2 | ust-ilimsk
# Processing Record 20 of Set 2 | bandarbeyla
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | cockburn town
# Processing Record 24 of Set 2 | yuanping
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | baiao
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | hualmay
# Processing Record 31 of Set 2 | kovdor
# Processing Record 32 of Set 2 | raahe
# Processing Record 33 of Set 2 | acarau
# Processing Record 34 of Set 2 | freeport
# Processing Record 35 of Set 2 | shupiyan
# Processing Record 36 of Set 2 | ixtapa
# Processing Record 37 of Set 2 | kroonstad
# Processing Record 38 of Set 2 | moerai
# Processing Record 39 of Set 2 | muisne
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | cap malheureux
# Processing Record 42 of Set 2 | ambon
# Processing Record 43 of Set 2 | moron
# Processing Record 44 of Set 2 | kez
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | huinan
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | santa cruz del sur
# Processing Record 49 of Set 2 | petrozavodsk
# Processing Record 50 of Set 2 | birjand
# Processing Record 1 of Set 3 | borgo san lorenzo
# Processing Record 2 of Set 3 | abu kamal
# Processing Record 3 of Set 3 | labuhan
# Processing Record 4 of Set 3 | krasnaya gorka
# Processing Record 5 of Set 3 | san patricio
# Processing Record 6 of Set 3 | buala
# Processing Record 7 of Set 3 | richards bay
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | alenquer
# Processing Record 10 of Set 3 | kayerkan
# Processing Record 11 of Set 3 | zhigansk
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | okhotsk
# Processing Record 14 of Set 3 | bull savanna
# Processing Record 15 of Set 3 | grand gaube
# Processing Record 16 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 3 | stromness
# Processing Record 18 of Set 3 | nouakchott
# Processing Record 19 of Set 3 | santiago
# Processing Record 20 of Set 3 | kamaishi
# Processing Record 21 of Set 3 | byumba
# Processing Record 22 of Set 3 | vikulovo
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | calvinia
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | gamba
# Processing Record 27 of Set 3 | taltal
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | saint george
# Processing Record 30 of Set 3 | pitkyaranta
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | kununurra
# Processing Record 34 of Set 3 | kearns
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | baneh
# Processing Record 37 of Set 3 | camana
# Processing Record 38 of Set 3 | farah
# Processing Record 39 of Set 3 | kruisfontein
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | saint-pierre
# Processing Record 42 of Set 3 | chinsali
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | zomba
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | tuatapere
# Processing Record 47 of Set 3 | la presa
# Processing Record 48 of Set 3 | zapolyarnyy
# Processing Record 49 of Set 3 | praia da vitoria
# Processing Record 50 of Set 3 | provideniya
# Processing Record 1 of Set 4 | pangai
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | nivala
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | maun
# Processing Record 6 of Set 4 | los llanos de aridane
# Processing Record 7 of Set 4 | xining
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 4 | pacific grove
# Processing Record 12 of Set 4 | wanganui
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 4 | poum
# Processing Record 16 of Set 4 | barra do garcas
# Processing Record 17 of Set 4 | pemangkat
# Processing Record 18 of Set 4 | puerto suarez
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | panzhihua
# Processing Record 21 of Set 4 | wewak
# Processing Record 22 of Set 4 | bubaque
# Processing Record 23 of Set 4 | paoua
# Processing Record 24 of Set 4 | gobabis
# Processing Record 25 of Set 4 | penzance
# Processing Record 26 of Set 4 | guicheng
# City not found. Skipping...
# Processing Record 27 of Set 4 | la sarre
# Processing Record 28 of Set 4 | shimanovsk
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | bethel
# Processing Record 33 of Set 4 | souillac
# Processing Record 34 of Set 4 | inuvik
# Processing Record 35 of Set 4 | pangnirtung
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | salalah
# Processing Record 38 of Set 4 | samarai
# Processing Record 39 of Set 4 | nea alikarnassos
# Processing Record 40 of Set 4 | pevek
# Processing Record 41 of Set 4 | namibe
# Processing Record 42 of Set 4 | minnedosa
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | apatou
# Processing Record 45 of Set 4 | mahajanga
# Processing Record 46 of Set 4 | kichera
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | krutinka
# Processing Record 50 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | wahiawa
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | pryazha
# Processing Record 5 of Set 5 | clyde river
# Processing Record 6 of Set 5 | hithadhoo
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | geraldton
# Processing Record 9 of Set 5 | goderich
# Processing Record 10 of Set 5 | katsuura
# Processing Record 11 of Set 5 | knevichi
# Processing Record 12 of Set 5 | ndele
# Processing Record 13 of Set 5 | hay river
# Processing Record 14 of Set 5 | dingle
# Processing Record 15 of Set 5 | cumberland
# Processing Record 16 of Set 5 | chokurdakh
# Processing Record 17 of Set 5 | caravelas
# Processing Record 18 of Set 5 | inta
# Processing Record 19 of Set 5 | hof
# Processing Record 20 of Set 5 | prachuap khiri khan
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | kendari
# Processing Record 23 of Set 5 | jacksonville
# Processing Record 24 of Set 5 | balkanabat
# Processing Record 25 of Set 5 | port augusta
# Processing Record 26 of Set 5 | presidencia roque saenz pena
# Processing Record 27 of Set 5 | san policarpo
# Processing Record 28 of Set 5 | chuy
# Processing Record 29 of Set 5 | viet tri
# Processing Record 30 of Set 5 | tooele
# Processing Record 31 of Set 5 | nabire
# Processing Record 32 of Set 5 | colotlan
# Processing Record 33 of Set 5 | jardim
# Processing Record 34 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 5 | nemuro
# Processing Record 36 of Set 5 | ponta delgada
# Processing Record 37 of Set 5 | passo de camaragibe
# Processing Record 38 of Set 5 | kasongo-lunda
# Processing Record 39 of Set 5 | dryden
# Processing Record 40 of Set 5 | east london
# Processing Record 41 of Set 5 | linfen
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | jizan
# Processing Record 44 of Set 5 | ossora
# Processing Record 45 of Set 5 | russell
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 5 | roma
# Processing Record 49 of Set 5 | emerald
# Processing Record 50 of Set 5 | marystown
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | milkovo
# Processing Record 4 of Set 6 | south daytona
# Processing Record 5 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 6 | alice springs
# Processing Record 7 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 6 | tezu
# Processing Record 9 of Set 6 | maniitsoq
# Processing Record 10 of Set 6 | shalya
# Processing Record 11 of Set 6 | mount gambier
# Processing Record 12 of Set 6 | krasnoborsk
# Processing Record 13 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 6 | kambove
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | namatanai
# Processing Record 17 of Set 6 | luderitz
# Processing Record 18 of Set 6 | troy
# Processing Record 19 of Set 6 | boyabat
# Processing Record 20 of Set 6 | palasa
# Processing Record 21 of Set 6 | cabo san lucas
# Processing Record 22 of Set 6 | hervey bay
# Processing Record 23 of Set 6 | miguel calmon
# Processing Record 24 of Set 6 | onalaska
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | nanortalik
# Processing Record 28 of Set 6 | ostrovnoy
# Processing Record 29 of Set 6 | sept-iles
# Processing Record 30 of Set 6 | port hedland
# Processing Record 31 of Set 6 | haines junction
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | te anau
# Processing Record 34 of Set 6 | zhezkazgan
# Processing Record 35 of Set 6 | baie-comeau
# Processing Record 36 of Set 6 | sakakah
# Processing Record 37 of Set 6 | leningradskiy
# Processing Record 38 of Set 6 | turayf
# Processing Record 39 of Set 6 | anaconda
# Processing Record 40 of Set 6 | saint-leu
# Processing Record 41 of Set 6 | tura
# Processing Record 42 of Set 6 | northam
# Processing Record 43 of Set 6 | jumla
# Processing Record 44 of Set 6 | tokur
# Processing Record 45 of Set 6 | bima
# Processing Record 46 of Set 6 | batabano
# Processing Record 47 of Set 6 | nizhniy ingash
# Processing Record 48 of Set 6 | plettenberg bay
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | indaiatuba
# Processing Record 1 of Set 7 | longyearbyen
# Processing Record 2 of Set 7 | coos bay
# Processing Record 3 of Set 7 | secovce
# Processing Record 4 of Set 7 | tayu
# Processing Record 5 of Set 7 | kalengwa
# Processing Record 6 of Set 7 | pangkalanbuun
# Processing Record 7 of Set 7 | puerto del rosario
# Processing Record 8 of Set 7 | macamic
# Processing Record 9 of Set 7 | oskarshamn
# Processing Record 10 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 7 | antofagasta
# Processing Record 12 of Set 7 | socorro
# Processing Record 13 of Set 7 | hasaki
# Processing Record 14 of Set 7 | vila franca do campo
# Processing Record 15 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 7 | santa maria
# Processing Record 17 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 7 | qianan
# Processing Record 20 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 7 | yara
# Processing Record 22 of Set 7 | mamakan
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | cumana
# Processing Record 25 of Set 7 | gazojak
# Processing Record 26 of Set 7 | sorland
# Processing Record 27 of Set 7 | ibia
# Processing Record 28 of Set 7 | port macquarie
# Processing Record 29 of Set 7 | aba
# Processing Record 30 of Set 7 | puyang
# Processing Record 31 of Set 7 | ayagoz
# Processing Record 32 of Set 7 | ginda
# Processing Record 33 of Set 7 | kavaratti
# Processing Record 34 of Set 7 | norrtalje
# Processing Record 35 of Set 7 | umm kaddadah
# Processing Record 36 of Set 7 | bairiki
# Processing Record 37 of Set 7 | paamiut
# Processing Record 38 of Set 7 | nagato
# Processing Record 39 of Set 7 | kiunga
# Processing Record 40 of Set 7 | jinji
# Processing Record 41 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 7 | keetmanshoop
# Processing Record 43 of Set 7 | rio gallegos
# Processing Record 44 of Set 7 | camalu
# Processing Record 45 of Set 7 | molchanovo
# Processing Record 46 of Set 7 | windhoek
# Processing Record 47 of Set 7 | kuusamo
# Processing Record 48 of Set 7 | havre-saint-pierre
# Processing Record 49 of Set 7 | takoradi
# Processing Record 50 of Set 7 | maryville
# Processing Record 1 of Set 8 | praia
# Processing Record 2 of Set 8 | kerrobert
# Processing Record 3 of Set 8 | high level
# Processing Record 4 of Set 8 | esperance
# Processing Record 5 of Set 8 | gazanjyk
# Processing Record 6 of Set 8 | thompson
# Processing Record 7 of Set 8 | progreso
# Processing Record 8 of Set 8 | troitskoye
# Processing Record 9 of Set 8 | saint anthony
# Processing Record 10 of Set 8 | sovetskiy
# Processing Record 11 of Set 8 | leh
# Processing Record 12 of Set 8 | kaimur
# City not found. Skipping...
# Processing Record 13 of Set 8 | aloleng
# Processing Record 14 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 8 | williams lake
# Processing Record 16 of Set 8 | husavik
# Processing Record 17 of Set 8 | torata
# Processing Record 18 of Set 8 | cairns
# Processing Record 19 of Set 8 | port shepstone
# Processing Record 20 of Set 8 | warrington
# Processing Record 21 of Set 8 | canutama
# Processing Record 22 of Set 8 | byron bay
# Processing Record 23 of Set 8 | xai-xai
# Processing Record 24 of Set 8 | alofi
# Processing Record 25 of Set 8 | camacha
# Processing Record 26 of Set 8 | cootamundra
# Processing Record 27 of Set 8 | kushima
# Processing Record 28 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 29 of Set 8 | ilo
# Processing Record 30 of Set 8 | vangaindrano
# Processing Record 31 of Set 8 | qui nhon
# Processing Record 32 of Set 8 | semnan
# Processing Record 33 of Set 8 | vanimo
# Processing Record 34 of Set 8 | ambilobe
# Processing Record 35 of Set 8 | lubango
# Processing Record 36 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 8 | korla
# Processing Record 38 of Set 8 | san carlos de bariloche
# Processing Record 39 of Set 8 | camden
# Processing Record 40 of Set 8 | brae
# Processing Record 41 of Set 8 | cullinan
# Processing Record 42 of Set 8 | muroto
# Processing Record 43 of Set 8 | lae
# Processing Record 44 of Set 8 | hovd
# Processing Record 45 of Set 8 | lahij
# Processing Record 46 of Set 8 | togur
# Processing Record 47 of Set 8 | ostersund
# Processing Record 48 of Set 8 | lusambo
# Processing Record 49 of Set 8 | tyukhtet
# Processing Record 50 of Set 8 | quimper
# Processing Record 1 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 9 | codrington
# Processing Record 4 of Set 9 | waipawa
# Processing Record 5 of Set 9 | banchory
# Processing Record 6 of Set 9 | guanica
# Processing Record 7 of Set 9 | luena
# Processing Record 8 of Set 9 | flinders
# Processing Record 9 of Set 9 | entre rios
# Processing Record 10 of Set 9 | axim
# Processing Record 11 of Set 9 | deer lake
# Processing Record 12 of Set 9 | itamaraju
# Processing Record 13 of Set 9 | lata
# Processing Record 14 of Set 9 | les ponts-de-ce
# Processing Record 15 of Set 9 | sainte-maxime
# Processing Record 16 of Set 9 | nizhniy tsasuchey
# Processing Record 17 of Set 9 | sabha
# Processing Record 18 of Set 9 | bonthe
# Processing Record 19 of Set 9 | kiruna
# Processing Record 20 of Set 9 | staryy nadym
# Processing Record 21 of Set 9 | auchi
# Processing Record 22 of Set 9 | dunedin
# Processing Record 23 of Set 9 | chicama
# Processing Record 24 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | makakilo city
# Processing Record 27 of Set 9 | aklavik
# Processing Record 28 of Set 9 | bukachacha
# Processing Record 29 of Set 9 | durango
# Processing Record 30 of Set 9 | ballina
# Processing Record 31 of Set 9 | baghdad
# Processing Record 32 of Set 9 | nantucket
# Processing Record 33 of Set 9 | ondjiva
# Processing Record 34 of Set 9 | gat
# Processing Record 35 of Set 9 | maputo
# Processing Record 36 of Set 9 | lufilufi
# Processing Record 37 of Set 9 | kety
# Processing Record 38 of Set 9 | ketchikan
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | kodiak
# Processing Record 41 of Set 9 | ciudad bolivar
# Processing Record 42 of Set 9 | ilulissat
# Processing Record 43 of Set 9 | da lat
# Processing Record 44 of Set 9 | tessalit
# Processing Record 45 of Set 9 | okha
# Processing Record 46 of Set 9 | guerrero negro
# Processing Record 47 of Set 9 | sur
# Processing Record 48 of Set 9 | aras
# Processing Record 49 of Set 9 | comodoro rivadavia
# Processing Record 50 of Set 9 | srednekolymsk
# Processing Record 1 of Set 10 | adrar
# Processing Record 2 of Set 10 | bathsheba
# Processing Record 3 of Set 10 | chickasha
# Processing Record 4 of Set 10 | mariel
# Processing Record 5 of Set 10 | mayo
# Processing Record 6 of Set 10 | vardo
# Processing Record 7 of Set 10 | susehri
# Processing Record 8 of Set 10 | pitimbu
# Processing Record 9 of Set 10 | mehamn
# Processing Record 10 of Set 10 | hengyang
# Processing Record 11 of Set 10 | mogadishu
# Processing Record 12 of Set 10 | abong mbang
# Processing Record 13 of Set 10 | puerto cabezas
# Processing Record 14 of Set 10 | coihaique
# Processing Record 15 of Set 10 | egvekinot
# Processing Record 16 of Set 10 | bograd
# Processing Record 17 of Set 10 | spring valley
# Processing Record 18 of Set 10 | port hardy
# Processing Record 19 of Set 10 | aasiaat
# Processing Record 20 of Set 10 | sidi bu zayd
# City not found. Skipping...
# Processing Record 21 of Set 10 | khani
# Processing Record 22 of Set 10 | kindu
# Processing Record 23 of Set 10 | crestview
# Processing Record 24 of Set 10 | kikwit
# Processing Record 25 of Set 10 | bolshoy uluy
# City not found. Skipping...
# Processing Record 26 of Set 10 | faanui
# Processing Record 27 of Set 10 | huanren
# Processing Record 28 of Set 10 | bokoro
# Processing Record 29 of Set 10 | bandipur
# Processing Record 30 of Set 10 | cururupu
# Processing Record 31 of Set 10 | pisco
# Processing Record 32 of Set 10 | alugan
# Processing Record 33 of Set 10 | belz
# Processing Record 34 of Set 10 | sola
# Processing Record 35 of Set 10 | san francisco
# Processing Record 36 of Set 10 | north bend
# Processing Record 37 of Set 10 | george town
# Processing Record 38 of Set 10 | ca mau
# Processing Record 39 of Set 10 | padang
# Processing Record 40 of Set 10 | lima
# Processing Record 41 of Set 10 | el alto
# Processing Record 42 of Set 10 | brewster
# Processing Record 43 of Set 10 | kachug
# Processing Record 44 of Set 10 | hofn
# Processing Record 45 of Set 10 | margate
# Processing Record 46 of Set 10 | cidreira
# Processing Record 47 of Set 10 | sipovo
# Processing Record 48 of Set 10 | lask
# Processing Record 49 of Set 10 | santa cruz de tenerife
# Processing Record 50 of Set 10 | garwolin
# Processing Record 1 of Set 11 | komsomolskoye
# Processing Record 2 of Set 11 | calama
# Processing Record 3 of Set 11 | buluang
# Processing Record 4 of Set 11 | morehead
# Processing Record 5 of Set 11 | jonesboro
# Processing Record 6 of Set 11 | balagansk
# Processing Record 7 of Set 11 | camocim
# Processing Record 8 of Set 11 | yulara
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | puerto colombia
# Processing Record 11 of Set 11 | tadine
# Processing Record 12 of Set 11 | eyl
# Processing Record 13 of Set 11 | jaro
# Processing Record 14 of Set 11 | madridejos
# Processing Record 15 of Set 11 | lauterbach
# Processing Record 16 of Set 11 | nedjo
# Processing Record 17 of Set 11 | tigil
# Processing Record 18 of Set 11 | venado tuerto
# Processing Record 19 of Set 11 | ahipara
# Processing Record 20 of Set 11 | cap-aux-meules
# Processing Record 21 of Set 11 | cravo norte
# Processing Record 22 of Set 11 | davila
# Processing Record 23 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 11 | evensk
# Processing Record 26 of Set 11 | yantongshan
# Processing Record 27 of Set 11 | hobyo
# Processing Record 28 of Set 11 | isla vista
# Processing Record 29 of Set 11 | hvolsvollur
# Processing Record 30 of Set 11 | lagunillas
# Processing Record 31 of Set 11 | azov
# Processing Record 32 of Set 11 | sorong
# Processing Record 33 of Set 11 | basco
# Processing Record 34 of Set 11 | ternate
# Processing Record 35 of Set 11 | pimenta bueno
# Processing Record 36 of Set 11 | marsa matruh
# Processing Record 37 of Set 11 | kaeo
# Processing Record 38 of Set 11 | mednogorskiy
# Processing Record 39 of Set 11 | rawson
# Processing Record 40 of Set 11 | strathmore
# Processing Record 41 of Set 11 | san rafael
# Processing Record 42 of Set 11 | vammala
# Processing Record 43 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 11 | boksitogorsk
# Processing Record 46 of Set 11 | sijunjung
# Processing Record 47 of Set 11 | kisangani
# Processing Record 48 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 49 of Set 11 | viedma
# Processing Record 50 of Set 11 | matara
# Processing Record 1 of Set 12 | port blair
# Processing Record 2 of Set 12 | monrovia
# Processing Record 3 of Set 12 | kyabram
# Processing Record 4 of Set 12 | taoudenni
# Processing Record 5 of Set 12 | chapais
# Processing Record 6 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 12 | kropotkin
# Processing Record 8 of Set 12 | fuerte
# Processing Record 9 of Set 12 | kurumkan
# Processing Record 10 of Set 12 | cheremshan
# Processing Record 11 of Set 12 | matamoros
# Processing Record 12 of Set 12 | broken hill
# Processing Record 13 of Set 12 | saint-francois
# Processing Record 14 of Set 12 | najran
# Processing Record 15 of Set 12 | pangody
# Processing Record 16 of Set 12 | olinda
# Processing Record 17 of Set 12 | puerto princesa
# Processing Record 18 of Set 12 | san matias
# Processing Record 19 of Set 12 | sao sebastiao
# Processing Record 20 of Set 12 | chateaurenard
# Processing Record 21 of Set 12 | iguala
# Processing Record 22 of Set 12 | drayton valley
# Processing Record 23 of Set 12 | zaysan
# Processing Record 24 of Set 12 | constitucion
# Processing Record 25 of Set 12 | mirai
# Processing Record 26 of Set 12 | omboue
# Processing Record 27 of Set 12 | killybegs
# Processing Record 28 of Set 12 | emmett
# Processing Record 29 of Set 12 | quattro castella
# Processing Record 30 of Set 12 | shingu
# Processing Record 31 of Set 12 | darhan
# Processing Record 32 of Set 12 | veraval
# Processing Record 33 of Set 12 | pemberton
# Processing Record 34 of Set 12 | synya
# Processing Record 35 of Set 12 | burnie
# Processing Record 36 of Set 12 | mozelos
# Processing Record 37 of Set 12 | dezhou
# Processing Record 38 of Set 12 | prince rupert
# Processing Record 39 of Set 12 | ussel
# Processing Record 40 of Set 12 | vagur
# Processing Record 41 of Set 12 | shebunino
# Processing Record 42 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 12 | beringovskiy
# Processing Record 44 of Set 12 | sanandaj
# Processing Record 45 of Set 12 | partapur
# Processing Record 46 of Set 12 | presidente medici
# Processing Record 47 of Set 12 | valleyview
# Processing Record 48 of Set 12 | noumea
# Processing Record 49 of Set 12 | nador
# Processing Record 50 of Set 12 | koumac
# Processing Record 1 of Set 13 | severo-yeniseyskiy
# Processing Record 2 of Set 13 | bengkulu
# Processing Record 3 of Set 13 | altayskoye
# Processing Record 4 of Set 13 | chazuta
# Processing Record 5 of Set 13 | kushmurun
# Processing Record 6 of Set 13 | altay
# Processing Record 7 of Set 13 | tulagi
# Processing Record 8 of Set 13 | ornskoldsvik
# Processing Record 9 of Set 13 | xinqing
# Processing Record 10 of Set 13 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 11 of Set 13 | hirara
# Processing Record 12 of Set 13 | queanbeyan
# Processing Record 13 of Set 13 | gualdo tadino
# Processing Record 14 of Set 13 | miri
# Processing Record 15 of Set 13 | batagay-alyta
# Processing Record 16 of Set 13 | rio grande
# Processing Record 17 of Set 13 | tawzar
# City not found. Skipping...
# Processing Record 18 of Set 13 | arlit
# Processing Record 19 of Set 13 | tongchuan
# Processing Record 20 of Set 13 | nome
# Processing Record 21 of Set 13 | hokitika
# Processing Record 22 of Set 13 | kagadi
# Processing Record 23 of Set 13 | banda aceh
# Processing Record 24 of Set 13 | tucurui
# Processing Record 25 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 26 of Set 13 | yanaul
# Processing Record 27 of Set 13 | takhli
# Processing Record 28 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | ozernovskiy
# Processing Record 30 of Set 13 | nha trang
# Processing Record 31 of Set 13 | palana
# Processing Record 32 of Set 13 | san cristobal
# Processing Record 33 of Set 13 | naze
# Processing Record 34 of Set 13 | san pedro
# Processing Record 35 of Set 13 | kulhudhuffushi
# Processing Record 36 of Set 13 | flic en flac
# Processing Record 37 of Set 13 | jacmel
# Processing Record 38 of Set 13 | vestmannaeyjar
# Processing Record 39 of Set 13 | beyneu
# Processing Record 40 of Set 13 | kuybysheve
# Processing Record 41 of Set 13 | sabang
# Processing Record 42 of Set 13 | machaneng
# Processing Record 43 of Set 13 | churapcha
# Processing Record 44 of Set 13 | obera
# Processing Record 45 of Set 13 | kargasok
# Processing Record 46 of Set 13 | tabory
# Processing Record 47 of Set 13 | bukama
# Processing Record 48 of Set 13 | key west
# Processing Record 49 of Set 13 | anchorage
# Processing Record 50 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 14 | manakara
# Processing Record 2 of Set 14 | rewari
# Processing Record 3 of Set 14 | vung tau
# Processing Record 4 of Set 14 | envira
# Processing Record 5 of Set 14 | guaruja
# Processing Record 6 of Set 14 | lazaro cardenas
# Processing Record 7 of Set 14 | ginir
# Processing Record 8 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 9 of Set 14 | half moon bay
# Processing Record 10 of Set 14 | qasigiannguit
# Processing Record 11 of Set 14 | pemba
# Processing Record 12 of Set 14 | isetskoye
# Processing Record 13 of Set 14 | cartagena del chaira
# Processing Record 14 of Set 14 | cuenca
# Processing Record 15 of Set 14 | airai
# Processing Record 16 of Set 14 | nurota
# Processing Record 17 of Set 14 | marzuq
# Processing Record 18 of Set 14 | malakal
# Processing Record 19 of Set 14 | sidi ali
# Processing Record 20 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 14 | aizpute
# Processing Record 22 of Set 14 | barra patuca
# Processing Record 23 of Set 14 | remanso
# Processing Record 24 of Set 14 | kalas
# Processing Record 25 of Set 14 | fuzhou
# Processing Record 26 of Set 14 | tiarei
# Processing Record 27 of Set 14 | tamworth
# Processing Record 28 of Set 14 | derzhavinsk
# Processing Record 29 of Set 14 | we
# City not found. Skipping...
# Processing Record 30 of Set 14 | baker city
# Processing Record 31 of Set 14 | xiaoshi
# Processing Record 32 of Set 14 | augustow
# Processing Record 33 of Set 14 | superior
# Processing Record 34 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 36 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 37 of Set 14 | sampit
# Processing Record 38 of Set 14 | maine-soroa
# Processing Record 39 of Set 14 | maragogi
# Processing Record 40 of Set 14 | laguna
# Processing Record 41 of Set 14 | cape elizabeth
# City not found. Skipping...
# Processing Record 42 of Set 14 | tambopata
# Processing Record 43 of Set 14 | vila
# Processing Record 44 of Set 14 | teknaf
# Processing Record 45 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 46 of Set 14 | tucuman
# Processing Record 47 of Set 14 | broome
# Processing Record 48 of Set 14 | ocana
# Processing Record 49 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 50 of Set 14 | port keats
# Processing Record 1 of Set 15 | kokrajhar
# Processing Record 2 of Set 15 | crotone
# Processing Record 3 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 15 | general roca
# Processing Record 5 of Set 15 | dali
# Processing Record 6 of Set 15 | solnechnyy
# Processing Record 7 of Set 15 | boyolangu
# Processing Record 8 of Set 15 | diamantino
# Processing Record 9 of Set 15 | sayabec
# City not found. Skipping...
# Processing Record 10 of Set 15 | zmeinogorsk
# Processing Record 11 of Set 15 | west bay
# Processing Record 12 of Set 15 | kresek
# Processing Record 13 of Set 15 | lasa
# Processing Record 14 of Set 15 | saint pete beach
# Processing Record 15 of Set 15 | rabat
# Processing Record 16 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 17 of Set 15 | trelew
# Processing Record 18 of Set 15 | sambava
# Processing Record 19 of Set 15 | linxia
# Processing Record 20 of Set 15 | grojdibodu
# Processing Record 21 of Set 15 | yerbogachen
# Processing Record 22 of Set 15 | stokmarknes
# Processing Record 23 of Set 15 | daru
# Processing Record 24 of Set 15 | cerrito
# Processing Record 25 of Set 15 | mayor pablo lagerenza
# Processing Record 26 of Set 15 | bonavista
# Processing Record 27 of Set 15 | wanaka
# Processing Record 28 of Set 15 | chorbog
# City not found. Skipping...
# Processing Record 29 of Set 15 | qaqortoq
# Processing Record 30 of Set 15 | santander jimenez
# Processing Record 31 of Set 15 | roald
# Processing Record 32 of Set 15 | zhuhai
# Processing Record 33 of Set 15 | rathdrum
# Processing Record 34 of Set 15 | kloulklubed
# Processing Record 35 of Set 15 | arman
# Processing Record 36 of Set 15 | svetlaya
# Processing Record 37 of Set 15 | kehychivka
# Processing Record 38 of Set 15 | saint-augustin
# Processing Record 39 of Set 15 | pingzhuang
# Processing Record 40 of Set 15 | zhangjiakou
# Processing Record 41 of Set 15 | westport
# Processing Record 42 of Set 15 | pedernales
# Processing Record 43 of Set 15 | kapoeta
# Processing Record 44 of Set 15 | outlook
# Processing Record 45 of Set 15 | saurimo
# Processing Record 46 of Set 15 | peniche
# Processing Record 47 of Set 15 | stanford
# Processing Record 48 of Set 15 | millinocket
# Processing Record 49 of Set 15 | kalmunai
# Processing Record 50 of Set 15 | myitkyina
# Processing Record 1 of Set 16 | san juan
# Processing Record 2 of Set 16 | anadyr
# Processing Record 3 of Set 16 | cabra
# Processing Record 4 of Set 16 | katherine
# Processing Record 5 of Set 16 | helong
# Processing Record 6 of Set 16 | tautira
# Processing Record 7 of Set 16 | faya
# Processing Record 8 of Set 16 | turukhansk
# Processing Record 9 of Set 16 | aswan
# Processing Record 10 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 16 | naryan-mar
# Processing Record 12 of Set 16 | acapulco
# Processing Record 13 of Set 16 | henties bay
# Processing Record 14 of Set 16 | gravdal
# Processing Record 15 of Set 16 | mandera
# Processing Record 16 of Set 16 | rosetown
# Processing Record 17 of Set 16 | toumodi
# Processing Record 18 of Set 16 | tilichiki
# Processing Record 19 of Set 16 | andra
# Processing Record 20 of Set 16 | samana
# Processing Record 21 of Set 16 | chingola
# Processing Record 22 of Set 16 | ishigaki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 709

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     38.82        60          20        9.22
# 1         Asau  46.4333   26.4000     69.28        55           0        3.24
# 2    Grindavik  63.8424  -22.4338     54.07       100         100       20.71
# 3         Surt  31.2089   16.5887     80.60        75           0        6.22
# 4       Hobart -42.8794  147.3294     44.46        93          69        8.05
# 5      Mataura -46.1927  168.8643     44.47        97         100        7.47
# 6    Saskylakh  71.9167  114.0833     66.27        85          28        4.21
# 7      Ouallam  14.3188    2.0866     94.46        40          54       19.37
# 8  Port Alfred -33.5906   26.8910     65.23        53          11        8.39
# 9      Rikitea -23.1203 -134.9692     75.43        75          97       13.15
#
#   Country                 Date Weather Description
# 0      AR  2022-07-26 19:44:23          few clouds
# 1      RO  2022-07-26 19:48:40           clear sky
# 2      IS  2022-07-26 19:48:40       moderate rain
# 3      LY  2022-07-26 19:48:41           clear sky
# 4      AU  2022-07-26 19:45:46       broken clouds
# 5      NZ  2022-07-26 19:45:35     overcast clouds
# 6      RU  2022-07-26 19:46:50    scattered clouds
# 7      NE  2022-07-26 19:48:42       broken clouds
# 8      ZA  2022-07-26 19:41:02          few clouds
# 9      PF  2022-07-26 19:41:49     overcast clouds

# %%
sample_city = city_data_df["City"]
sample_latitude = city_data_df["Lat"]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 new_df = [sample_city, sample_latitude]
#       2 new_df.head()
#
# NameError: name 'sample_city' is not defined
