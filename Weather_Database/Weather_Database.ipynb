# %% [markdown]
# ## Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#import Citypy
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import requests
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # print(city) or # print (i, city) 
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
     # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    #print(city_url)
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append(
            {
                "City": city.title(),
                "Lat": city_lat,
                "Lng": city_lng,
                "Max Temp": city_max_temp,
                "Humidity": city_humidity,
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
                "Country": city_country,
                "Weather Description":city_weather_description 
            })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | rio grande
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | sinnamary
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | westport
# Processing Record 13 of Set 1 | szigetujfalu
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | sidney
# Processing Record 18 of Set 1 | vestbygda
# City not found. Skipping...
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | huangchuan
# Processing Record 22 of Set 1 | jibuti
# Processing Record 23 of Set 1 | eloy
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | fortuna
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | bontang
# Processing Record 30 of Set 1 | tiznit
# Processing Record 31 of Set 1 | svetlogorsk
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | mirnyy
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | dubna
# Processing Record 37 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | shaunavon
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | havre-saint-pierre
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | uryupinsk
# Processing Record 2 of Set 2 | ballina
# Processing Record 3 of Set 2 | agde
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | ponta delgada
# Processing Record 9 of Set 2 | taldan
# Processing Record 10 of Set 2 | ruthin
# Processing Record 11 of Set 2 | shizunai
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | chkalovsk
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 2 | constitucion
# Processing Record 17 of Set 2 | salinopolis
# Processing Record 18 of Set 2 | mbumi
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 24 of Set 2 | staunton
# Processing Record 25 of Set 2 | soyo
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 2 | sterling
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | saint anthony
# Processing Record 31 of Set 2 | san cataldo
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | olafsvik
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | plettenberg bay
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | san quintin
# Processing Record 41 of Set 2 | bathsheba
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | klishkivtsi
# Processing Record 44 of Set 2 | dalvik
# Processing Record 45 of Set 2 | ilo
# Processing Record 46 of Set 2 | caravelas
# Processing Record 47 of Set 2 | seoul
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | dingle
# Processing Record 50 of Set 2 | rincon de tamayo
# Processing Record 1 of Set 3 | grand gaube
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | pombas
# Processing Record 4 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 3 | grindavik
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | santa fe
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | bam
# Processing Record 11 of Set 3 | salima
# Processing Record 12 of Set 3 | longyearbyen
# Processing Record 13 of Set 3 | enid
# Processing Record 14 of Set 3 | bennettsville
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | buchanan
# Processing Record 17 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 3 | flinders
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | pokosnoye
# Processing Record 21 of Set 3 | victoria
# Processing Record 22 of Set 3 | henties bay
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | kargat
# Processing Record 25 of Set 3 | maceio
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | san cristobal
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | kununurra
# Processing Record 30 of Set 3 | sorong
# Processing Record 31 of Set 3 | qasigiannguit
# Processing Record 32 of Set 3 | pathein
# Processing Record 33 of Set 3 | adzope
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | cayenne
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | sulangan
# Processing Record 38 of Set 3 | conde
# Processing Record 39 of Set 3 | hohhot
# Processing Record 40 of Set 3 | berdigestyakh
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | baykit
# Processing Record 44 of Set 3 | husavik
# Processing Record 45 of Set 3 | kamina
# Processing Record 46 of Set 3 | ulaangom
# Processing Record 47 of Set 3 | vestmanna
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | obo
# Processing Record 2 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 4 | maragogi
# Processing Record 4 of Set 4 | baiyin
# Processing Record 5 of Set 4 | zenzeli
# Processing Record 6 of Set 4 | bloomfield
# Processing Record 7 of Set 4 | abu kamal
# Processing Record 8 of Set 4 | lakes entrance
# Processing Record 9 of Set 4 | saint-augustin
# Processing Record 10 of Set 4 | san jose
# Processing Record 11 of Set 4 | cravo norte
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | tautira
# Processing Record 14 of Set 4 | mulege
# Processing Record 15 of Set 4 | ndola
# Processing Record 16 of Set 4 | margate
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 4 | berlevag
# Processing Record 21 of Set 4 | yerbogachen
# Processing Record 22 of Set 4 | impfondo
# Processing Record 23 of Set 4 | durres
# Processing Record 24 of Set 4 | sambava
# Processing Record 25 of Set 4 | kapaa
# Processing Record 26 of Set 4 | faanui
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | hit
# Processing Record 29 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 4 | balabac
# Processing Record 31 of Set 4 | williams lake
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | katherine
# Processing Record 34 of Set 4 | kalemie
# Processing Record 35 of Set 4 | mayo
# Processing Record 36 of Set 4 | yulara
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | tucuma
# Processing Record 39 of Set 4 | oistins
# Processing Record 40 of Set 4 | east london
# Processing Record 41 of Set 4 | pemangkat
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | ciudad ojeda
# Processing Record 44 of Set 4 | caibarien
# Processing Record 45 of Set 4 | marshfield
# Processing Record 46 of Set 4 | narsaq
# Processing Record 47 of Set 4 | komsomolskiy
# Processing Record 48 of Set 4 | talnakh
# Processing Record 49 of Set 4 | bubaque
# Processing Record 50 of Set 4 | shu
# Processing Record 1 of Set 5 | evanston
# Processing Record 2 of Set 5 | lazaro cardenas
# Processing Record 3 of Set 5 | bilma
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 5 | yashkul
# Processing Record 7 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 5 | nogliki
# Processing Record 9 of Set 5 | taybad
# Processing Record 10 of Set 5 | englehart
# Processing Record 11 of Set 5 | san jeronimo
# Processing Record 12 of Set 5 | patacamaya
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | roswell
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 5 | huambo
# Processing Record 19 of Set 5 | goundam
# Processing Record 20 of Set 5 | moose factory
# Processing Record 21 of Set 5 | manor
# Processing Record 22 of Set 5 | san policarpo
# Processing Record 23 of Set 5 | havelock
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | iqaluit
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | phibun mangsahan
# Processing Record 28 of Set 5 | krokeai
# Processing Record 29 of Set 5 | coihaique
# Processing Record 30 of Set 5 | half moon bay
# Processing Record 31 of Set 5 | lavrentiya
# Processing Record 32 of Set 5 | jinchang
# Processing Record 33 of Set 5 | tessalit
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | kandi
# Processing Record 36 of Set 5 | novopokrovka
# Processing Record 37 of Set 5 | katangli
# Processing Record 38 of Set 5 | korla
# Processing Record 39 of Set 5 | ivanovka
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | lanivtsi
# Processing Record 42 of Set 5 | ixtapa
# Processing Record 43 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | ilulissat
# Processing Record 45 of Set 5 | niquelandia
# Processing Record 46 of Set 5 | port hardy
# Processing Record 47 of Set 5 | atambua
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 5 | laguna
# Processing Record 1 of Set 6 | karratha
# Processing Record 2 of Set 6 | santa cruz del sur
# Processing Record 3 of Set 6 | mao
# Processing Record 4 of Set 6 | claudio
# Processing Record 5 of Set 6 | leningradskiy
# Processing Record 6 of Set 6 | leh
# Processing Record 7 of Set 6 | arraial do cabo
# Processing Record 8 of Set 6 | de aar
# Processing Record 9 of Set 6 | izumo
# Processing Record 10 of Set 6 | pevek
# Processing Record 11 of Set 6 | ossora
# Processing Record 12 of Set 6 | belmonte
# Processing Record 13 of Set 6 | fairbanks
# Processing Record 14 of Set 6 | rong kwang
# Processing Record 15 of Set 6 | carutapera
# Processing Record 16 of Set 6 | lima
# Processing Record 17 of Set 6 | mahebourg
# Processing Record 18 of Set 6 | buritizeiro
# Processing Record 19 of Set 6 | camacha
# Processing Record 20 of Set 6 | kuytun
# Processing Record 21 of Set 6 | mogadishu
# Processing Record 22 of Set 6 | gamba
# Processing Record 23 of Set 6 | dallas
# Processing Record 24 of Set 6 | pokhara
# Processing Record 25 of Set 6 | norden
# Processing Record 26 of Set 6 | airai
# Processing Record 27 of Set 6 | inta
# Processing Record 28 of Set 6 | hambantota
# Processing Record 29 of Set 6 | oparino
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | nioro
# Processing Record 32 of Set 6 | high level
# Processing Record 33 of Set 6 | college
# Processing Record 34 of Set 6 | avera
# Processing Record 35 of Set 6 | orlik
# Processing Record 36 of Set 6 | tabarqah
# City not found. Skipping...
# Processing Record 37 of Set 6 | weinan
# Processing Record 38 of Set 6 | tazovskiy
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | didwana
# Processing Record 41 of Set 6 | vikhorevka
# Processing Record 42 of Set 6 | lucea
# Processing Record 43 of Set 6 | bireun
# Processing Record 44 of Set 6 | oriximina
# Processing Record 45 of Set 6 | mount gambier
# Processing Record 46 of Set 6 | shakawe
# Processing Record 47 of Set 6 | faya
# Processing Record 48 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 6 | flin flon
# Processing Record 50 of Set 6 | huilong
# Processing Record 1 of Set 7 | sao gabriel da cachoeira
# Processing Record 2 of Set 7 | lakatoro
# Processing Record 3 of Set 7 | ola
# Processing Record 4 of Set 7 | benjamin aceval
# Processing Record 5 of Set 7 | nipawin
# Processing Record 6 of Set 7 | lithakia
# Processing Record 7 of Set 7 | aklavik
# Processing Record 8 of Set 7 | cam ranh
# Processing Record 9 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 10 of Set 7 | ende
# Processing Record 11 of Set 7 | namatanai
# Processing Record 12 of Set 7 | mount isa
# Processing Record 13 of Set 7 | biak
# Processing Record 14 of Set 7 | teknaf
# Processing Record 15 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 16 of Set 7 | buala
# Processing Record 17 of Set 7 | buin
# Processing Record 18 of Set 7 | motygino
# Processing Record 19 of Set 7 | puerto escondido
# Processing Record 20 of Set 7 | buraydah
# Processing Record 21 of Set 7 | vanimo
# Processing Record 22 of Set 7 | pangnirtung
# Processing Record 23 of Set 7 | fort nelson
# Processing Record 24 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 7 | sur
# Processing Record 26 of Set 7 | weiser
# Processing Record 27 of Set 7 | muros
# Processing Record 28 of Set 7 | kewanee
# Processing Record 29 of Set 7 | qaqortoq
# Processing Record 30 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 7 | changji
# Processing Record 33 of Set 7 | balakovo
# Processing Record 34 of Set 7 | lasa
# Processing Record 35 of Set 7 | digha
# Processing Record 36 of Set 7 | goderich
# Processing Record 37 of Set 7 | asau
# Processing Record 38 of Set 7 | te anau
# Processing Record 39 of Set 7 | saint-francois
# Processing Record 40 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 7 | gat
# Processing Record 42 of Set 7 | litovko
# Processing Record 43 of Set 7 | wajir
# Processing Record 44 of Set 7 | domoni
# Processing Record 45 of Set 7 | alappuzha
# Processing Record 46 of Set 7 | peleduy
# Processing Record 47 of Set 7 | state college
# Processing Record 48 of Set 7 | tura
# Processing Record 49 of Set 7 | el silencio
# Processing Record 50 of Set 7 | burnie
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | byron bay
# Processing Record 3 of Set 8 | preobrazheniye
# Processing Record 4 of Set 8 | inhambane
# Processing Record 5 of Set 8 | sarkand
# Processing Record 6 of Set 8 | santa isabel do rio negro
# Processing Record 7 of Set 8 | tehachapi
# Processing Record 8 of Set 8 | hovd
# Processing Record 9 of Set 8 | bozoum
# Processing Record 10 of Set 8 | san patricio
# Processing Record 11 of Set 8 | coquimbo
# Processing Record 12 of Set 8 | salalah
# Processing Record 13 of Set 8 | sitka
# Processing Record 14 of Set 8 | alekseyevka
# Processing Record 15 of Set 8 | trelew
# Processing Record 16 of Set 8 | los llanos de aridane
# Processing Record 17 of Set 8 | mosquera
# Processing Record 18 of Set 8 | uvinza
# Processing Record 19 of Set 8 | grajau
# Processing Record 20 of Set 8 | port moresby
# Processing Record 21 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 22 of Set 8 | huarmey
# Processing Record 23 of Set 8 | santa cruz
# Processing Record 24 of Set 8 | maxixe
# Processing Record 25 of Set 8 | ninghai
# Processing Record 26 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 8 | usolye
# Processing Record 28 of Set 8 | saint george
# Processing Record 29 of Set 8 | fougamou
# Processing Record 30 of Set 8 | haines junction
# Processing Record 31 of Set 8 | karia
# Processing Record 32 of Set 8 | norrtalje
# Processing Record 33 of Set 8 | revuca
# Processing Record 34 of Set 8 | iralaya
# Processing Record 35 of Set 8 | gladstone
# Processing Record 36 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 8 | grand-santi
# Processing Record 38 of Set 8 | lagoa
# Processing Record 39 of Set 8 | umm kaddadah
# Processing Record 40 of Set 8 | brejo santo
# Processing Record 41 of Set 8 | viedma
# Processing Record 42 of Set 8 | natchitoches
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | dubai
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | muravlenko
# Processing Record 47 of Set 8 | souillac
# Processing Record 48 of Set 8 | yunyang
# Processing Record 49 of Set 8 | la ronge
# Processing Record 50 of Set 8 | hasaki
# Processing Record 1 of Set 9 | thilogne
# City not found. Skipping...
# Processing Record 2 of Set 9 | asheville
# Processing Record 3 of Set 9 | dunedin
# Processing Record 4 of Set 9 | cockburn town
# Processing Record 5 of Set 9 | darhan
# Processing Record 6 of Set 9 | balakhninskiy
# Processing Record 7 of Set 9 | tuka
# Processing Record 8 of Set 9 | new bern
# Processing Record 9 of Set 9 | sistranda
# Processing Record 10 of Set 9 | singaraja
# Processing Record 11 of Set 9 | beitbridge
# Processing Record 12 of Set 9 | eldoret
# Processing Record 13 of Set 9 | chimbote
# Processing Record 14 of Set 9 | beisfjord
# Processing Record 15 of Set 9 | sahuaripa
# Processing Record 16 of Set 9 | marsh harbour
# Processing Record 17 of Set 9 | vostok
# Processing Record 18 of Set 9 | sidi qasim
# City not found. Skipping...
# Processing Record 19 of Set 9 | cristalina
# Processing Record 20 of Set 9 | maumere
# Processing Record 21 of Set 9 | marawi
# Processing Record 22 of Set 9 | opuwo
# Processing Record 23 of Set 9 | coahuayana
# Processing Record 24 of Set 9 | la asuncion
# Processing Record 25 of Set 9 | poum
# Processing Record 26 of Set 9 | tuatapere
# Processing Record 27 of Set 9 | usinsk
# Processing Record 28 of Set 9 | sawang daen din
# Processing Record 29 of Set 9 | formosa
# Processing Record 30 of Set 9 | baoqing
# Processing Record 31 of Set 9 | prince george
# Processing Record 32 of Set 9 | xining
# Processing Record 33 of Set 9 | sorland
# Processing Record 34 of Set 9 | verkhnyaya inta
# Processing Record 35 of Set 9 | adrar
# Processing Record 36 of Set 9 | mecca
# Processing Record 37 of Set 9 | baniachang
# Processing Record 38 of Set 9 | vila franca do campo
# Processing Record 39 of Set 9 | rio gallegos
# Processing Record 40 of Set 9 | kailua
# Processing Record 41 of Set 9 | daru
# Processing Record 42 of Set 9 | skibbereen
# Processing Record 43 of Set 9 | roebourne
# Processing Record 44 of Set 9 | lalmohan
# Processing Record 45 of Set 9 | luderitz
# Processing Record 46 of Set 9 | steinbach
# Processing Record 47 of Set 9 | jumla
# Processing Record 48 of Set 9 | turukhansk
# Processing Record 49 of Set 9 | dolores
# Processing Record 50 of Set 9 | hue
# Processing Record 1 of Set 10 | maksatikha
# Processing Record 2 of Set 10 | teya
# Processing Record 3 of Set 10 | palu
# Processing Record 4 of Set 10 | assiniboia
# Processing Record 5 of Set 10 | pudozh
# Processing Record 6 of Set 10 | paka
# Processing Record 7 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 8 of Set 10 | srednekolymsk
# Processing Record 9 of Set 10 | gari
# Processing Record 10 of Set 10 | dongsheng
# Processing Record 11 of Set 10 | yubari
# Processing Record 12 of Set 10 | wajima
# Processing Record 13 of Set 10 | naryan-mar
# Processing Record 14 of Set 10 | mangrol
# Processing Record 15 of Set 10 | ngunguru
# Processing Record 16 of Set 10 | hunterville
# Processing Record 17 of Set 10 | mehamn
# Processing Record 18 of Set 10 | ketchikan
# Processing Record 19 of Set 10 | orotukan
# Processing Record 20 of Set 10 | vao
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | qixingtai
# Processing Record 23 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 24 of Set 10 | tecoanapa
# Processing Record 25 of Set 10 | nagorsk
# Processing Record 26 of Set 10 | maubin
# Processing Record 27 of Set 10 | fujin
# Processing Record 28 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 29 of Set 10 | lerwick
# Processing Record 30 of Set 10 | cabrera
# Processing Record 31 of Set 10 | hualmay
# Processing Record 32 of Set 10 | iskandar
# Processing Record 33 of Set 10 | cheyenne
# Processing Record 34 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 10 | kloulklubed
# Processing Record 36 of Set 10 | port hedland
# Processing Record 37 of Set 10 | cortland
# Processing Record 38 of Set 10 | harper
# Processing Record 39 of Set 10 | arlit
# Processing Record 40 of Set 10 | puerto madryn
# Processing Record 41 of Set 10 | mackay
# Processing Record 42 of Set 10 | wewak
# Processing Record 43 of Set 10 | krasnokamensk
# Processing Record 44 of Set 10 | abbeyfeale
# Processing Record 45 of Set 10 | lodwar
# Processing Record 46 of Set 10 | boyolangu
# Processing Record 47 of Set 10 | vitim
# Processing Record 48 of Set 10 | junqueiro
# Processing Record 49 of Set 10 | roma
# Processing Record 50 of Set 10 | tianpeng
# Processing Record 1 of Set 11 | acapulco
# Processing Record 2 of Set 11 | dutlwe
# Processing Record 3 of Set 11 | kenitra
# Processing Record 4 of Set 11 | koslan
# Processing Record 5 of Set 11 | urumqi
# Processing Record 6 of Set 11 | abnub
# Processing Record 7 of Set 11 | shenavan
# Processing Record 8 of Set 11 | haapiti
# Processing Record 9 of Set 11 | sterlibashevo
# Processing Record 10 of Set 11 | nushki
# Processing Record 11 of Set 11 | kisangani
# Processing Record 12 of Set 11 | shenjiamen
# Processing Record 13 of Set 11 | mehran
# Processing Record 14 of Set 11 | mersing
# Processing Record 15 of Set 11 | charlestown
# Processing Record 16 of Set 11 | lincoln
# Processing Record 17 of Set 11 | codrington
# Processing Record 18 of Set 11 | sainte-marie
# Processing Record 19 of Set 11 | penaflor
# Processing Record 20 of Set 11 | chimore
# Processing Record 21 of Set 11 | kavieng
# Processing Record 22 of Set 11 | banda aceh
# Processing Record 23 of Set 11 | arroio grande
# Processing Record 24 of Set 11 | necochea
# Processing Record 25 of Set 11 | uaua
# Processing Record 26 of Set 11 | billings
# Processing Record 27 of Set 11 | sol-iletsk
# Processing Record 28 of Set 11 | dukat
# Processing Record 29 of Set 11 | gumdag
# Processing Record 30 of Set 11 | hamilton
# Processing Record 31 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 33 of Set 11 | guerrero negro
# Processing Record 34 of Set 11 | madingou
# Processing Record 35 of Set 11 | panaba
# Processing Record 36 of Set 11 | luau
# Processing Record 37 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 11 | rosario
# Processing Record 39 of Set 11 | gandorhun
# Processing Record 40 of Set 11 | west lorne
# Processing Record 41 of Set 11 | mumford
# Processing Record 42 of Set 11 | gashua
# Processing Record 43 of Set 11 | aktash
# Processing Record 44 of Set 11 | santa teresita
# Processing Record 45 of Set 11 | troitskoye
# Processing Record 46 of Set 11 | halifax
# Processing Record 47 of Set 11 | aswan
# Processing Record 48 of Set 11 | urucuca
# Processing Record 49 of Set 11 | cochrane
# Processing Record 50 of Set 11 | shangrao
# Processing Record 1 of Set 12 | anadyr
# Processing Record 2 of Set 12 | lokosovo
# Processing Record 3 of Set 12 | andenes
# Processing Record 4 of Set 12 | fonte boa
# Processing Record 5 of Set 12 | awjilah
# Processing Record 6 of Set 12 | ambovombe
# Processing Record 7 of Set 12 | roberval
# Processing Record 8 of Set 12 | mango
# Processing Record 9 of Set 12 | quatre cocos
# Processing Record 10 of Set 12 | mayumba
# Processing Record 11 of Set 12 | auki
# Processing Record 12 of Set 12 | beloha
# Processing Record 13 of Set 12 | cairns
# Processing Record 14 of Set 12 | yar-sale
# Processing Record 15 of Set 12 | dharchula
# Processing Record 16 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 12 | quelimane
# Processing Record 19 of Set 12 | port macquarie
# Processing Record 20 of Set 12 | chunhuhub
# Processing Record 21 of Set 12 | porto walter
# Processing Record 22 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 12 | ruteng
# Processing Record 24 of Set 12 | pitea
# Processing Record 25 of Set 12 | sao filipe
# Processing Record 26 of Set 12 | the valley
# Processing Record 27 of Set 12 | bonavista
# Processing Record 28 of Set 12 | tezu
# Processing Record 29 of Set 12 | indramayu
# Processing Record 30 of Set 12 | nome
# Processing Record 31 of Set 12 | road town
# Processing Record 32 of Set 12 | matagami
# Processing Record 33 of Set 12 | kibre mengist
# Processing Record 34 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 12 | palmas
# Processing Record 36 of Set 12 | dali
# Processing Record 37 of Set 12 | warmbad
# Processing Record 38 of Set 12 | komsomolets
# Processing Record 39 of Set 12 | charters towers
# Processing Record 40 of Set 12 | armizonskoye
# Processing Record 41 of Set 12 | urucara
# Processing Record 42 of Set 12 | lethem
# Processing Record 43 of Set 12 | palana
# Processing Record 44 of Set 12 | bani
# Processing Record 45 of Set 12 | talcahuano
# Processing Record 46 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 12 | centerville
# Processing Record 48 of Set 12 | iracoubo
# Processing Record 49 of Set 12 | gravdal
# Processing Record 50 of Set 12 | siverek
# Processing Record 1 of Set 13 | periyanayakkanpalaiyam
# Processing Record 2 of Set 13 | langsa
# Processing Record 3 of Set 13 | san francisco
# Processing Record 4 of Set 13 | kokorevka
# Processing Record 5 of Set 13 | balakhta
# Processing Record 6 of Set 13 | paracuru
# Processing Record 7 of Set 13 | nuuk
# Processing Record 8 of Set 13 | bakchar
# Processing Record 9 of Set 13 | baherden
# Processing Record 10 of Set 13 | batemans bay
# Processing Record 11 of Set 13 | shingu
# Processing Record 12 of Set 13 | namibe
# Processing Record 13 of Set 13 | nouadhibou
# Processing Record 14 of Set 13 | marfino
# Processing Record 15 of Set 13 | porto velho
# Processing Record 16 of Set 13 | ust-maya
# Processing Record 17 of Set 13 | kostomuksha
# Processing Record 18 of Set 13 | sinop
# Processing Record 19 of Set 13 | edremit
# Processing Record 20 of Set 13 | vila do maio
# Processing Record 21 of Set 13 | ural
# Processing Record 22 of Set 13 | royan
# Processing Record 23 of Set 13 | itarema
# Processing Record 24 of Set 13 | vaitape
# Processing Record 25 of Set 13 | kuah
# Processing Record 26 of Set 13 | otradnoye
# Processing Record 27 of Set 13 | zharkent
# Processing Record 28 of Set 13 | puebla
# Processing Record 29 of Set 13 | yilan
# Processing Record 30 of Set 13 | birao
# Processing Record 31 of Set 13 | savignano sul rubicone
# Processing Record 32 of Set 13 | makakilo city
# Processing Record 33 of Set 13 | dauphin
# Processing Record 34 of Set 13 | sola
# Processing Record 35 of Set 13 | olinda
# Processing Record 36 of Set 13 | roald
# Processing Record 37 of Set 13 | portoferraio
# Processing Record 38 of Set 13 | boundiali
# Processing Record 39 of Set 13 | bayji
# Processing Record 40 of Set 13 | jishou
# Processing Record 41 of Set 13 | cazones
# Processing Record 42 of Set 13 | springbok
# Processing Record 43 of Set 13 | hirado
# Processing Record 44 of Set 13 | labuhan
# Processing Record 45 of Set 13 | sayat
# Processing Record 46 of Set 13 | marzuq
# Processing Record 47 of Set 13 | mongomo
# Processing Record 48 of Set 13 | peterhead
# Processing Record 49 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 13 | broken hill
# Processing Record 1 of Set 14 | santa maria
# Processing Record 2 of Set 14 | bonthe
# Processing Record 3 of Set 14 | guia lopes da laguna
# Processing Record 4 of Set 14 | stokmarknes
# Processing Record 5 of Set 14 | vardo
# Processing Record 6 of Set 14 | varlamovo
# Processing Record 7 of Set 14 | saint-pierre
# Processing Record 8 of Set 14 | erie
# Processing Record 9 of Set 14 | colac
# Processing Record 10 of Set 14 | mayor pablo lagerenza
# Processing Record 11 of Set 14 | west lafayette
# Processing Record 12 of Set 14 | stillwater
# Processing Record 13 of Set 14 | rabo de peixe
# Processing Record 14 of Set 14 | bandarbeyla
# Processing Record 15 of Set 14 | atar
# Processing Record 16 of Set 14 | yumen
# Processing Record 17 of Set 14 | nyimba
# Processing Record 18 of Set 14 | egvekinot
# Processing Record 19 of Set 14 | moerai
# Processing Record 20 of Set 14 | miles city
# Processing Record 21 of Set 14 | kamaishi
# Processing Record 22 of Set 14 | heihe
# Processing Record 23 of Set 14 | richards bay
# Processing Record 24 of Set 14 | kose-uuemoisa
# City not found. Skipping...
# Processing Record 25 of Set 14 | tual
# Processing Record 26 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 14 | waterloo
# Processing Record 28 of Set 14 | broome
# Processing Record 29 of Set 14 | ewa beach
# Processing Record 30 of Set 14 | bintulu
# Processing Record 31 of Set 14 | maamba
# Processing Record 32 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 14 | najran
# Processing Record 34 of Set 14 | greece
# Processing Record 35 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 36 of Set 14 | jizan
# Processing Record 37 of Set 14 | teguise
# Processing Record 38 of Set 14 | kindu
# Processing Record 39 of Set 14 | eureka
# Processing Record 40 of Set 14 | shache
# Processing Record 41 of Set 14 | ambilobe
# Processing Record 42 of Set 14 | marrakesh
# Processing Record 43 of Set 14 | wanning
# Processing Record 44 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 14 | nakhon thai
# Processing Record 46 of Set 14 | barkhera
# Processing Record 47 of Set 14 | piracuruca
# Processing Record 48 of Set 14 | autlan
# City not found. Skipping...
# Processing Record 49 of Set 14 | popondetta
# Processing Record 50 of Set 14 | freeport
# Processing Record 1 of Set 15 | la tuque
# Processing Record 2 of Set 15 | puerres
# Processing Record 3 of Set 15 | coromandel
# Processing Record 4 of Set 15 | kangaba
# Processing Record 5 of Set 15 | cap malheureux
# Processing Record 6 of Set 15 | dengzhou
# Processing Record 7 of Set 15 | hailar
# Processing Record 8 of Set 15 | bonito oriental
# Processing Record 9 of Set 15 | salmas
# Processing Record 10 of Set 15 | zhenhai
# Processing Record 11 of Set 15 | jilmah
# City not found. Skipping...
# Processing Record 12 of Set 15 | katobu
# Processing Record 13 of Set 15 | strezhevoy
# Processing Record 14 of Set 15 | moshi
# Processing Record 15 of Set 15 | benghazi
# Processing Record 16 of Set 15 | gucheng
# Processing Record 17 of Set 15 | yatou
# Processing Record 18 of Set 15 | bafra
# Processing Record 19 of Set 15 | katesh
# Processing Record 20 of Set 15 | alexandria
# Processing Record 21 of Set 15 | progreso
# Processing Record 22 of Set 15 | zyryanka
# Processing Record 23 of Set 15 | le mars
# Processing Record 24 of Set 15 | phatthalung
# Processing Record 25 of Set 15 | illapel
# Processing Record 26 of Set 15 | sumbe
# Processing Record 27 of Set 15 | brae
# Processing Record 28 of Set 15 | esso
# Processing Record 29 of Set 15 | nishihara
# Processing Record 30 of Set 15 | borba
# Processing Record 31 of Set 15 | san marco in lamis
# Processing Record 32 of Set 15 | singleton
# Processing Record 33 of Set 15 | rundu
# Processing Record 34 of Set 15 | ust-kut
# Processing Record 35 of Set 15 | renqiu
# Processing Record 36 of Set 15 | eyl
# Processing Record 37 of Set 15 | okhotsk
# Processing Record 38 of Set 15 | susangerd
# Processing Record 39 of Set 15 | samarai
# Processing Record 40 of Set 15 | anjiang
# Processing Record 41 of Set 15 | yantai
# Processing Record 42 of Set 15 | priyutovo
# Processing Record 43 of Set 15 | requena
# Processing Record 44 of Set 15 | honningsvag
# Processing Record 45 of Set 15 | yokosuka
# Processing Record 46 of Set 15 | gold coast
# Processing Record 47 of Set 15 | iskateley
# Processing Record 48 of Set 15 | sassandra
# Processing Record 49 of Set 15 | chernyshevskiy
# Processing Record 50 of Set 15 | ucluelet
# Processing Record 1 of Set 16 | iquitos
# Processing Record 2 of Set 16 | paamiut
# Processing Record 3 of Set 16 | jinchengjiang
# City not found. Skipping...
# Processing Record 4 of Set 16 | salisbury
# Processing Record 5 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 16 | deer lake
# Processing Record 7 of Set 16 | las vegas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#city_data_df.columns
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Bredasdorp -34.5322   20.0403     49.93        94          68
# 1  Mar Del Plata -38.0023  -57.5575     55.09        98         100
# 2     Rio Grande -32.0350  -52.0986     62.71        97          51
# 3     Chokurdakh  70.6333  147.9167     55.87        42          47
# 4      Sinnamary   5.3833  -52.9500     79.07        81          22
# 5     Nikolskoye  59.7035   30.7861     64.29        91          95
# 6        Ahipara -35.1667  173.1667     59.14        73          98
# 7      Cape Town -33.9258   18.4232     54.12        90          41
# 8   Puerto Ayora  -0.7393  -90.3518     70.56        92         100
# 9      Hithadhoo  -0.6000   73.0833     77.43        89         100
#
#    Wind Speed Country   Weather Description
# 0        5.95      ZA         broken clouds
# 1        1.99      AR       overcast clouds
# 2        8.48      BR         broken clouds
# 3       10.78      RU      scattered clouds
# 4        5.53      GF            few clouds
# 5        4.85      RU       overcast clouds
# 6       11.97      NZ       overcast clouds
# 7        1.01      ZA      scattered clouds
# 8        3.00      EC       overcast clouds
# 9       16.69      MV  heavy intensity rain

# %%
#reorder columns
new_column_order = [ "City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Bredasdorp      ZA -34.5322   20.0403     49.93        94          68
# 1  Mar Del Plata      AR -38.0023  -57.5575     55.09        98         100
# 2     Rio Grande      BR -32.0350  -52.0986     62.71        97          51
# 3     Chokurdakh      RU  70.6333  147.9167     55.87        42          47
# 4      Sinnamary      GF   5.3833  -52.9500     79.07        81          22
# 5     Nikolskoye      RU  59.7035   30.7861     64.29        91          95
# 6        Ahipara      NZ -35.1667  173.1667     59.14        73          98
# 7      Cape Town      ZA -33.9258   18.4232     54.12        90          41
# 8   Puerto Ayora      EC  -0.7393  -90.3518     70.56        92         100
# 9      Hithadhoo      MV  -0.6000   73.0833     77.43        89         100
#
#    Wind Speed   Weather Description
# 0        5.95         broken clouds
# 1        1.99       overcast clouds
# 2        8.48         broken clouds
# 3       10.78      scattered clouds
# 4        5.53            few clouds
# 5        4.85       overcast clouds
# 6       11.97       overcast clouds
# 7        1.01      scattered clouds
# 8        3.00       overcast clouds
# 9       16.69  heavy intensity rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
